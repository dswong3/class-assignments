# %% [markdown]
# #in terminal - how to make new clean file w/o titles
#
# tail -n+18 pbdb_data.csv > cleanpbdb.csv

# %%
#open the file
infile = "canids/cleanpbdb.csv"
with open(infile, 'r') as ff:
    canid_recs = ff.readlines()[1:]

# %%
#make a dictionary

for line in canid_recs: 
    print(line.split(",")[5])
# Out:
# "accepted_name"
# "Cynodictis lacustris"
# "Cuon"
# "Hesperocyon"
# "Neovulpavus washakius"
# "Hesperocyon"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Canidae"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon"
# "Hesperocyon"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon"
# "Hesperocyon"
# "Hesperocyon gregarius"
# "Hesperocyon"
# "Hesperocyon"
# "Hesperocyon gregarius"
# "Hesperocyon"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon"
# "Hesperocyon"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Canidae"
# "Hesperocyon gregarius"
# "Hesperocyon"
# "Hesperocyon gregarius"
# "Hesperocyon"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# "Hesperocyon gregarius"
# ...

# %%
for line in canid_recs: 
    print(line.split(",")[5])
    minage = line.split('","')[10]
    maxage = line.split(",")[11]
    print(minage)
    #mean_age = (minage + maxage) / 2
    #print (mean_age)
# Out:
# "Cynodictis lacustris"
# 37.2
# "Cuon"
# 0.781
# "Hesperocyon"
# 46.2
# "Neovulpavus washakius"
# 46.2
# "Hesperocyon"
# 40.4
# "Hesperocyon gregarius"
# 40.4
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Canidae"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon gregarius"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon"
# 37.2
# "Hesperocyon gregarius"
# ...

# %%
for line in canid_recs: 
    species = line.split(",")[5]
    minage = float(line.split('","')[10])
    maxage = float(line.split('","')[11])
    mean_age = (minage + maxage / 2)
    print (mean_age)
# Out:
# 54.150000000000006
# 0.78685
# 66.4
# 66.4
# 57.349999999999994
# 59.0
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# 54.150000000000006
# ...

# %%
from collections import defaultdict
species_ranges = defaultdict(list)

for line in canid_recs: 
    species = line.split(",")[5]
    minage = (float(line.split('","')[10]))
    maxage = float((line.split('","')[11]))
    mean_age = (minage + maxage) / 2
    
    species_ranges[species].append(mean_age) #add species as keys and mean ages as elements to the list of ages
    #print (mean_age)

# %% [markdown]
#     Get the oldest and youngest ages of fossils for each species in species_ranges

# %%
output = open("canid-ranges.csv", "w")


for key in species_ranges.keys():
    ages = species_ranges[key]
    minage = min(ages)
    maxage = max(ages)
    genus = key.split(" ")[0]
    print(genus, key, minage, maxage)
    output.write(genus + "," + key )
# Out:
# "Oxetocyon "Oxetocyon cuspidatus" 32.05 32.05
# "Canis "Canis armbrusteri" 0.06885 2.6
# "Ectopocynus "Ectopocynus simplicidens" 18.2 18.2
# "Metalopex "Metalopex macconnelli" 11.95 14.1815
# "Cuon" "Cuon" 0.06885 0.4535
# "Canis "Canis thooides" 3.35 3.35
# "Carpocyon "Carpocyon limosus" 7.6000000000000005 7.6000000000000005
# "Metatomarctus" "Metatomarctus" 14.1815 14.1815
# "Oxetocyon" "Oxetocyon" 32.05 32.05
# "Canini" "Canini" 3.35 7.6000000000000005
# "Leptocyon "Leptocyon tejonensis" 11.95 11.95
# "Canis "Canis edwardii" 1.05 14.1815
# "Aelurodon "Aelurodon ferox" 9.25 14.785
# "Paraenhydrocyon "Paraenhydrocyon wallovianus" 22.615000000000002 25.615000000000002
# "Desmocyon "Desmocyon matthewi" 18.2 18.2
# "Cynodictis" "Cynodictis" 31.0 52.2
# "Canis "Canis aureus" 0.00585 3.0940000000000003
# "Cynodesmus "Cynodesmus martini" 25.615000000000002 25.615000000000002
# "Xenocyon" "Xenocyon" 0.4535 1.6845
# "Vulpes "Vulpes kernensis" 11.95 11.95
# ...

# %%
output = open("canid-ranges.csv", "w")


for key in species_ranges.keys():
    ages = species_ranges[key]
    minage = min(ages)
    maxage = max(ages)
    genus = key.split(" ")[0]
    species = key
    #print(genus, key, minage, maxage)
    outline = "{},{},{},{}\n".format(genus, species, minage, maxage)
    #print outline
    output.write(outline)

# %%
import os
from collections import defaultdict

os.chdir("/home/eeb177-student/Desktop/eeb-177/class-assignments/classwork-2-March/canids/cleanpbdb.csv")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-5-97b8d4130762> in <module>()
#       2 from collections import defaultdict
#       3
# ----> 4 os.chdir("/home/eeb177-student/Desktop/eeb-177/class-assignments/classwork-2-March/canids/cleanpbdb.csv")
#
# NotADirectoryError: [Errno 20] Not a directory: '/home/eeb177-student/Desktop/eeb-177/class-assignments/classwork-2-March/canids/cleanpbdb.csv'
